# %%
import torch
import torch.nn.functional as F
from torch import nn


class CenteredLayer(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, X):
        return X - X.mean()

# %%
layer = CenteredLayer()
layer(torch.FloatTensor([1, 2, 3, 4, 5]))
# Out:
# tensor([-2., -1.,  0.,  1.,  2.])

# %%
net = nn.Sequential(nn.Linear(8, 128), CenteredLayer())

# %%
Y = net(torch.rand(4, 8))
Y.mean()
# Out:
# tensor(5.5879e-09, grad_fn=<MeanBackward0>)

# %%
class MyLinear(nn.Module):
    def __init__(self, in_units, units):
        super().__init__()
        self.weight = nn.Parameter(torch.randn(in_units, units))
        self.bias = nn.Parameter(torch.randn(units,))
    def forward(self, X):
        linear = torch.matmul(X, self.weight.data) + self.bias.data
        return F.relu(linear)

# %%
linear = MyLinear(5, 3)
linear.weight
# Out:
# Parameter containing:
# tensor([[ 1.4501, -0.6779, -1.0085],
#         [ 0.6436, -1.1348,  1.2841],
#         [ 0.7625, -1.0834,  0.3185],
#         [ 2.2953,  1.5010,  1.0036],
#         [ 0.1678, -0.0503,  0.5345]], requires_grad=True)

# %%
linear(torch.rand(2, 5))
# Out:
# tensor([[2.5102, 0.0000, 1.8611],
#         [2.8845, 0.0000, 2.3553]])

# %%
net = nn.Sequential(MyLinear(64, 8), MyLinear(8, 1))
net(torch.rand(2, 64))
# Out:
# tensor([[0.0000],
#         [1.6926]])

# %% [markdown]
# named_parameters()的用法，因为其返回的是一个迭代器，所以访问是要在for循环中访问，并用两个参数来接收它

# %%
for name, param in net.named_parameters():
    print(name, param)
# Out:
# 0.weight Parameter containing:
# tensor([[ 0.6767, -0.9463,  0.0729, -0.7194,  0.0044,  2.9269,  0.6308,  0.0359],
#         [-0.4147, -0.5932, -1.8727,  0.1398,  0.1084, -1.3612,  0.2159,  1.7722],
#         [ 1.0150,  1.5477, -0.8887,  0.0078,  0.0247,  0.7180, -0.5159,  1.2353],
#         [ 1.2624, -0.7854,  0.2429, -0.1433,  1.5152, -0.3669, -0.0358,  1.2142],
#         [-0.0065,  0.0478,  0.3753,  0.6810, -0.1199,  2.0344, -1.8449, -0.3373],
#         [ 0.3094,  0.6463,  0.4752, -0.2605,  0.9843, -0.7700, -1.4067, -1.6815],
#         [-1.0596, -0.4426,  0.3403,  0.1628, -0.7078, -0.2570, -0.7920, -1.3645],
#         [ 0.4612, -0.0172,  1.2038,  1.2423,  0.1893, -0.8509,  2.3262,  1.4448],
#         [-0.4506,  0.6799,  0.4561, -0.3370, -1.3604, -1.3694, -1.1338,  1.2169],
#         [ 0.4461,  1.1958, -1.8547, -0.9699, -0.0277, -0.0315, -2.1106, -0.6221],
#         [ 0.1748, -1.4248,  0.5598, -1.1912,  0.1092, -0.4359, -0.0076, -0.4169],
#         [ 0.0974,  0.9876,  0.6487,  0.2755,  1.2006,  1.4148,  0.3875, -0.9880],
#         [ 0.9684,  0.0322, -0.5510,  0.3819,  0.9410,  0.3548, -0.0150,  0.8768],
#         [ 0.5543,  1.7076, -0.4490,  0.0857, -1.5871,  1.4723,  0.0809, -0.2076],
#         [ 1.4264, -0.6442, -0.0772,  1.3980, -0.2449, -0.1465, -2.6998, -1.1883],
#         [ 1.4445,  0.8467,  0.0791, -0.3776, -0.2686,  0.9709, -0.3062, -1.2244],
#         [ 0.6392,  0.1756,  1.1951,  1.5025,  1.2824,  0.7746, -0.7873,  0.5487],
#         [-0.5552,  0.2873,  0.1526,  0.9001, -2.1068, -1.7244,  0.1948, -0.3152],
#         [-0.9129,  0.7075,  1.7983,  1.0098,  0.5649,  0.2223,  1.7333, -3.0267],
#         [-0.8010,  1.1774, -0.2784,  2.0516, -1.2425, -1.1042,  0.6999,  0.1786],
#         [ 0.3235,  0.2681, -0.8506, -0.8001,  0.6036, -1.6139,  1.0160, -1.2464],
#         [-1.5754, -1.1874,  0.6630,  1.1922,  0.6979,  0.5389,  0.7125, -0.7490],
#         [-0.5198,  0.3938,  0.9315,  0.1757,  1.4728,  1.0822, -0.2151, -0.4530],
#         [ 0.5856, -0.6996, -0.3148,  0.9052,  1.5434, -0.7874, -1.5919, -1.2401],
#         [-0.3896,  1.2142, -2.4396, -0.0931,  0.5833,  0.2963,  0.1401, -0.9280],
#         [ 0.8087, -2.0451, -0.3010, -2.0203, -0.5904, -0.0067,  0.0108,  0.5142],
#         [ 0.6467, -0.9817, -0.0938, -0.2875, -0.7563, -0.0412,  2.7685,  0.5559],
#         [-0.8220, -0.9076, -0.9552,  1.6192,  1.5144, -0.3755, -0.7499,  1.7487],
#         [ 1.8778, -1.0329, -0.7171,  1.2045, -0.0971,  2.7894,  0.2445,  1.0531],
#         [-0.7669,  0.8040,  0.6633, -0.8000, -0.2277, -0.1275,  0.5592, -0.3786],
#         [-0.0699, -0.2417, -1.3370, -0.5153,  1.0465, -0.4898, -1.4464,  0.2294],
#         [-1.2591, -0.8344, -0.7771, -0.9607, -0.8457,  0.1792,  1.2302, -0.9803],
#         [-0.1243,  0.8173,  0.4621,  1.5855,  0.6465,  0.8355,  0.0952,  0.2405],
#         [ 0.3077,  0.5272, -0.7613, -0.6422,  0.3563, -1.6035,  2.1519, -1.4896],
#         [-1.3861, -2.0795, -0.5313,  0.2969, -0.0624,  0.1262, -0.0193, -1.0646],
#         [ 0.3188,  0.7364, -0.7344, -0.2625, -0.4903,  2.1170, -0.7290,  0.0775]],
#        requires_grad=True)
# 0.bias Parameter containing:
# tensor([ 0.6502, -0.7839, -1.2984, -0.0340, -1.7197,  0.3701,  0.1730,  1.2022],
#        requires_grad=True)
# 1.weight Parameter containing:
# tensor([[ 0.9637],
#         [ 0.5475],
#         [-2.3283],
#         [-0.8234],
#         [ 0.6231],
#         [ 0.0271],
#         [ 1.4332],
#         [-0.5602]], requires_grad=True)
# 1.bias Parameter containing:
# tensor([0.1336], requires_grad=True)
